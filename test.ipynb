# %%
import yaml
import numpy as np


config = yaml.safe_load(open('configLyaFit.yaml'))
list(config['FixedParameters'].keys())
# Out:
# ['Redshift', 'ExpV', 'LogN', 'Tau', 'Flux', 'LogEW', 'IntrinsicW', 'TP']

# %%
array = np.array([1,2,3,4,5,6,7])
array[::-1]
# Out:
# array([7, 6, 5, 4, 3, 2, 1])

# %%
import Lya_zelda_II as Lya

# %%
Lya?
# Out:
# Type:        module
# String form: <module 'Lya_zelda_II' from '/home/ojedarcelo/.local/lib/python3.10/site-packages/Lya_zelda_II/__init__.py'>
# File:        ~/.local/lib/python3.10/site-packages/Lya_zelda_II/__init__.py
# Docstring:   <no docstring>
